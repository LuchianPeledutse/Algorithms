# %%
import numpy as np
import time
import random as rd 
import pandas as pd
from x_of_2_sum import n2_2_sum,nlogn_2_sum
from quick_sort import QuickSort
import sys

# %%
sys.setrecursionlimit(10000)

# %% [markdown]
# ### Merge,insertion,quick

# %%
#Merge that is needed for MergeSort
def Merge(A,p,q,r):
	#len(A) > 1 as p<=q<r
	n1 = q-p+1
	n2 = r-q
	#create left and right sequences
	L = [1 for _ in range(n1)]
	R = [1 for _ in range(n2)]
	#filling them up
	for k in range(n1):
		L[k] = A[p+k]
	for k in range(n2):
		R[k] = A[q+k+1]
	#sorting in non-decreasing order
	i,j = 0,0
	for ind in range(p,r+1):
		if i+1 > n1:
			A[ind] = R[j]
			j += 1
		elif j+1 > n2:
			A[ind] = L[i]
			i += 1
		else:
			if L[i] <= R[j]:
				A[ind] = L[i]
				i += 1
			else:
				A[ind] = R[j]
				j += 1

#merge_sort
def MergeSort(A,p,r):
	#here we have p<=r
	#if p = r nothing is done
	if p<r:
		q = int((p+r)/2)
		#q satisfies p<=q<r
		MergeSort(A,p,q)
		MergeSort(A,q+1,r)
		Merge(A,p,q,r)

#insertion_sort
def insertion_sort(A):
	N = len(A)
	for j in range(1,N):
		key = A[j]
		i = j-1
		while i>=0 and A[i]>key:
			A[i+1] = A[i]
			i -= 1
		A[i+1] = key

# %%
def test_merge(N):
	for k in range(N):
		rand_ar = [rd.randint(1,99) for _ in range(11)]
		py_sort = list(sorted(rand_ar))
		print(f'Python_sort: {py_sort}')
		print(f'Initital_list: {rand_ar}')
		MergeSort(rand_ar,0,len(rand_ar)-1)
		print(f'MergeSort: {rand_ar}',end = '\n\n')
		if rand_ar != list(sorted(rand_ar)):
			print('#################WRONG#################')


def test_ins_sort(N):
	for k in range(N):
		rand_ar = [rd.randint(1,99) for _ in range(10)]
		py_sort = list(sorted(rand_ar))
		print(f'Python_sort: {py_sort}')
		print(f'Initital_list: {rand_ar}')
		insertion_sort(rand_ar)
		print(f'Insertion_sort: {rand_ar}',end = '\n\n')
		if rand_ar != list(sorted(rand_ar)):
			print('#################WRONG#################')

def test_quick_sort(N):
	for k in range(N):
		rand_ar = [rd.randint(1,99) for _ in range(10)]
		py_sort = list(sorted(rand_ar))
		print(f'Python_sort: {py_sort}')
		print(f'QuickSort_list: {rand_ar}')
		QuickSort(rand_ar,0,len(rand_ar)-1)
		print(f'QuickSort_sort: {rand_ar}',end = '\n\n')
		if rand_ar != list(sorted(rand_ar)):
			print('#################WRONG#################')

# %%
N = 5
test_merge(N)
print(end = '\n\n')
test_ins_sort(N)
print(end = '\n\n')
test_quick_sort(N)
# Out:
# Python_sort: [5, 11, 20, 25, 44, 58, 61, 63, 65, 79, 94]
# Initital_list: [58, 94, 11, 79, 44, 65, 61, 63, 25, 5, 20]
# MergeSort: [5, 11, 20, 25, 44, 58, 61, 63, 65, 79, 94]
#
# Python_sort: [5, 26, 27, 38, 42, 45, 51, 52, 57, 91, 95]
# Initital_list: [45, 5, 52, 38, 27, 91, 26, 51, 42, 95, 57]
# MergeSort: [5, 26, 27, 38, 42, 45, 51, 52, 57, 91, 95]
#
# Python_sort: [21, 23, 23, 24, 52, 57, 64, 68, 80, 96, 97]
# Initital_list: [24, 52, 68, 80, 23, 96, 23, 57, 64, 21, 97]
# MergeSort: [21, 23, 23, 24, 52, 57, 64, 68, 80, 96, 97]
#
# Python_sort: [8, 21, 52, 57, 63, 64, 81, 85, 90, 97, 97]
# Initital_list: [97, 57, 52, 21, 8, 81, 63, 97, 90, 64, 85]
# MergeSort: [8, 21, 52, 57, 63, 64, 81, 85, 90, 97, 97]
#
# Python_sort: [2, 3, 5, 5, 11, 22, 42, 48, 52, 53, 86]
# Initital_list: [3, 53, 42, 86, 5, 22, 5, 52, 2, 11, 48]
# MergeSort: [2, 3, 5, 5, 11, 22, 42, 48, 52, 53, 86]
#
#
#
# Python_sort: [1, 1, 13, 20, 34, 40, 66, 66, 77, 82]
# Initital_list: [34, 1, 40, 66, 66, 13, 82, 1, 20, 77]
# Insertion_sort: [1, 1, 13, 20, 34, 40, 66, 66, 77, 82]
#
# Python_sort: [13, 25, 34, 55, 67, 68, 75, 76, 84, 94]
# Initital_list: [76, 13, 67, 34, 55, 25, 94, 68, 75, 84]
# Insertion_sort: [13, 25, 34, 55, 67, 68, 75, 76, 84, 94]
#
# Python_sort: [3, 3, 21, 22, 52, 60, 76, 86, 87, 92]
# Initital_list: [60, 3, 21, 92, 52, 87, 86, 76, 3, 22]
# Insertion_sort: [3, 3, 21, 22, 52, 60, 76, 86, 87, 92]
#
# Python_sort: [22, 28, 38, 43, 44, 64, 72, 84, 90, 92]
# Initital_list: [28, 64, 38, 90, 44, 22, 92, 72, 43, 84]
# Insertion_sort: [22, 28, 38, 43, 44, 64, 72, 84, 90, 92]
#
# Python_sort: [12, 17, 21, 24, 24, 30, 43, 70, 83, 99]
# Initital_list: [17, 83, 21, 24, 70, 12, 24, 99, 30, 43]
# Insertion_sort: [12, 17, 21, 24, 24, 30, 43, 70, 83, 99]
#
#
#
# Python_sort: [1, 5, 17, 44, 59, 68, 72, 78, 78, 92]
# QuickSort_list: [17, 59, 92, 1, 44, 78, 68, 72, 78, 5]
# QuickSort_sort: [1, 5, 17, 44, 59, 68, 72, 78, 78, 92]
#
# Python_sort: [1, 4, 9, 12, 24, 36, 85, 86, 86, 87]
# QuickSort_list: [87, 86, 12, 85, 24, 1, 9, 36, 4, 86]
# QuickSort_sort: [1, 4, 9, 12, 24, 36, 85, 86, 86, 87]
#
# Python_sort: [1, 32, 35, 40, 46, 49, 49, 60, 88, 99]
# QuickSort_list: [1, 49, 99, 46, 60, 49, 35, 40, 88, 32]
# QuickSort_sort: [1, 32, 35, 40, 46, 49, 49, 60, 88, 99]
#
# Python_sort: [3, 20, 34, 41, 41, 45, 59, 71, 82, 91]
# QuickSort_list: [59, 71, 41, 82, 41, 34, 45, 20, 3, 91]
# QuickSort_sort: [3, 20, 34, 41, 41, 45, 59, 71, 82, 91]
#
# Python_sort: [1, 29, 33, 36, 38, 47, 63, 64, 79, 86]
# QuickSort_list: [63, 1, 29, 36, 64, 38, 33, 86, 47, 79]
# QuickSort_sort: [1, 29, 33, 36, 38, 47, 63, 64, 79, 86]

# %%
#time of 100_000 elements of MergeSort
some_ar = [rd.randint(1,99) for _ in range(200_000)]
start_time = time.time()
MergeSort(some_ar,0,len(some_ar)-1)
end_time = time.time()
print(f'Mergesort_time:{end_time-start_time:.6f} seconds')
# Out:
# Mergesort_time:0.506997 seconds

# %%
#time of 100_000 elements of MergeSort
some_ar = [rd.randint(1,99) for _ in range(200_000)]
start_time = time.time()
QuickSort(some_ar,0,len(some_ar)-1)
end_time = time.time()
print(f'Quicksort_time:{end_time-start_time:.6f} seconds')
# Out:
# Quicksort_time:10.190126 seconds

# %%
#time of 100_000 elements of InsertionSort
start_time = time.time()
some_ar = [rd.randint(1,99) for _ in range(100_000)]
insertion_sort(some_ar)
end_time = time.time()
print(f'Insertion_sort_time:{end_time-start_time:.6f} seconds')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 4
#       2 start_time = time.time()
#       3 some_ar = [rd.randint(1,99) for _ in range(100_000)]
# ----> 4 insertion_sort(some_ar)
#       5 end_time = time.time()
#       6 print(f'Insertion_sort_time:{end_time-start_time:.6f} seconds')
#
# Cell In[4], line 48, in insertion_sort(A)
#      46 key = A[j]
#      47 i = j-1
# ---> 48 while i>=0 and A[i]>key:
#      49 	A[i+1] = A[i]
#      50 	i -= 1
#
# KeyboardInterrupt:

# %%
main_table = pd.DataFrame({
    'Algorithms':['MergeSort','Insertion_sort'],
    'Time':[0.286280,115.499474]
})
main_table
# Out:
#        Algorithms        Time
# 0       MergeSort    0.286280
# 1  Insertion_sort  115.499474

# %% [markdown]
# ### Two sum n^2 and nlogn comparisons

# %%
def measure_execution_time(func, args_list):
    start_time = time.perf_counter()  
    func(*args_list) 
    end_time = time.perf_counter()
    return round(end_time - start_time,5)

# %%
def time_test(N = 10):
    for _ in range(N):
        rand_shape = rd.randint(10_000,25_000)
        main_list = [rd.randint(1000,1500) for  _ in range(rand_shape)]
        random_find = rd.randint(1000,1500)
        print(f'Time of O(n^2): {measure_execution_time(n2_2_sum,[main_list,random_find])}')
        print(f'Time of O(nlogn): {measure_execution_time(nlogn_2_sum,[main_list,random_find])}',end = '\n\n')

# %%
time_test(N = 5)
# Out:
# Time of O(n^2): 2.37546
# Time of O(nlogn): 0.00202
#
# Time of O(n^2): 3.92043
# Time of O(nlogn): 0.00268
#
# Time of O(n^2): 2.8519
# Time of O(nlogn): 0.00223
#
# Time of O(n^2): 4.91939
# Time of O(nlogn): 0.003
#
# Time of O(n^2): 8.26149
# Time of O(nlogn): 0.00399

# %%
# now we check whether they match at all

# %%
def match_test(N = 100):
    for _ in range(N):
        rand_shape = rd.randint(10_000,25_000)
        main_list = [rd.randint(500,1500) for  _ in range(rand_shape)]
        random_find = rd.randint(1000,1500)
        print(f'Test # {_+1}')
        res1 = n2_2_sum(main_list,random_find)
        res2 = nlogn_2_sum(main_list,random_find)
        if  res1 == res2:
            print('PASSED')
            print(res1,res2)
        else:
            print('###WRONG###')
            break

# %%
match_test()
# Out:
# Test # 1
# PASSED
# True True
# Test # 2
# PASSED
# True True
# Test # 3
# PASSED
# True True
# Test # 4
# PASSED
# True True
# Test # 5
# PASSED
# True True
# Test # 6
# PASSED
# True True
# Test # 7
# PASSED
# True True
# Test # 8
# PASSED
# True True
# Test # 9
# PASSED
# True True
# Test # 10
# PASSED
# True True
# Test # 11
# PASSED
# True True
# Test # 12
# PASSED
# True True
# Test # 13
# PASSED
# True True
# Test # 14
# PASSED
# True True
# Test # 15
# PASSED
# True True
# Test # 16
# PASSED
# True True
# Test # 17
# PASSED
# True True
# Test # 18
# PASSED
# True True
# Test # 19
# PASSED
# True True
# Test # 20
# PASSED
# True True
# Test # 21
# PASSED
# True True
# Test # 22
# PASSED
# True True
# Test # 23
# PASSED
# True True
# Test # 24
# PASSED
# True True
# Test # 25
# PASSED
# True True
# Test # 26
# PASSED
# True True
# Test # 27
# PASSED
# True True
# Test # 28
# PASSED
# True True
# Test # 29
# PASSED
# True True
# Test # 30
# PASSED
# True True
# Test # 31
# PASSED
# True True
# Test # 32
# PASSED
# True True
# Test # 33
# PASSED
# True True
# Test # 34
# PASSED
# True True
# Test # 35
# PASSED
# True True
# Test # 36
# PASSED
# True True
# Test # 37
# PASSED
# True True
# Test # 38
# PASSED
# True True
# Test # 39
# PASSED
# True True
# Test # 40
# PASSED
# True True
# Test # 41
# PASSED
# True True
# Test # 42
# PASSED
# True True
# Test # 43
# PASSED
# True True
# Test # 44
# PASSED
# True True
# Test # 45
# PASSED
# True True
# Test # 46
# PASSED
# True True
# Test # 47
# PASSED
# True True
# Test # 48
# PASSED
# True True
# Test # 49
# PASSED
# True True
# Test # 50
# PASSED
# True True
# Test # 51
# PASSED
# True True
# Test # 52
# PASSED
# True True
# Test # 53
# PASSED
# True True
# Test # 54
# PASSED
# True True
# Test # 55
# PASSED
# True True
# Test # 56
# PASSED
# True True
# Test # 57
# PASSED
# True True
# Test # 58
# PASSED
# True True
# Test # 59
# PASSED
# True True
# Test # 60
# PASSED
# True True
# Test # 61
# PASSED
# True True
# Test # 62
# PASSED
# True True
# Test # 63
# PASSED
# True True
# Test # 64
# PASSED
# True True
# Test # 65
# PASSED
# True True
# Test # 66
# PASSED
# True True
# Test # 67
# PASSED
# True True
# Test # 68
# PASSED
# True True
# Test # 69
# PASSED
# True True
# Test # 70
# PASSED
# True True
# Test # 71
# PASSED
# True True
# Test # 72
# PASSED
# True True
# Test # 73
# PASSED
# True True
# Test # 74
# PASSED
# True True
# Test # 75
# PASSED
# True True
# Test # 76
# PASSED
# True True
# Test # 77
# PASSED
# True True
# Test # 78
# PASSED
# True True
# Test # 79
# PASSED
# True True
# Test # 80
# PASSED
# True True
# Test # 81
# PASSED
# True True
# Test # 82
# PASSED
# True True
# Test # 83
# PASSED
# True True
# Test # 84
# PASSED
# True True
# Test # 85
# PASSED
# True True
# Test # 86
# PASSED
# True True
# Test # 87
# PASSED
# True True
# Test # 88
# PASSED
# True True
# Test # 89
# PASSED
# True True
# Test # 90
# PASSED
# True True
# Test # 91
# PASSED
# True True
# Test # 92
# PASSED
# True True
# Test # 93
# PASSED
# True True
# Test # 94
# PASSED
# True True
# Test # 95
# PASSED
# True True
# Test # 96
# PASSED
# True True
# Test # 97
# PASSED
# True True
# Test # 98
# PASSED
# True True
# Test # 99
# PASSED
# True True
# Test # 100
# PASSED
# True True
